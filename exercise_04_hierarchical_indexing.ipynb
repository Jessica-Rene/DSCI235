# %% [markdown]
# # Exercise 4: Hierarchical Indexing in pandas
# <span style="color: brown;">Jessica Reyes</span>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# This set of exercises focuses on hierarchical indexing.  First, let's create some data that includes data for three individuals ('A', 'B', 'C') across several years:

# %%
data_list = [ [1977, 'A', 1.20, 0.60], 
        [1977, 'B', 1.50, 0.50], 
        [1977, 'C', 1.70, 0.80],
        [1978, 'A', 0.20, 0.06],
        [1978, 'B', 0.70, 0.20],
        [1978, 'C', 0.80, 0.30],
        [1978, 'D', 0.90, 0.50],
        [1978, 'E', 1.40, 0.90],
        [1979, 'C', 0.20, 0.15],
        [1979, 'D', 0.14, 0.05],
        [1979, 'E', 0.50, 0.15],
        [1979, 'F', 1.20, 0.50],
        [1979, 'G', 3.40, 1.90],
        [1979, 'H', 5.40, 2.70],
        [1979, 'I', 6.40, 1.20] ]
data = pd.DataFrame(data_list, columns=['year', 'indiv', 'x', 'z'])
data
# Out:
#     year indiv     x     z
# 0   1977     A  1.20  0.60
# 1   1977     B  1.50  0.50
# 2   1977     C  1.70  0.80
# 3   1978     A  0.20  0.06
# 4   1978     B  0.70  0.20
# 5   1978     C  0.80  0.30
# 6   1978     D  0.90  0.50
# 7   1978     E  1.40  0.90
# 8   1979     C  0.20  0.15
# 9   1979     D  0.14  0.05
# 10  1979     E  0.50  0.15
# 11  1979     F  1.20  0.50
# 12  1979     G  3.40  1.90
# 13  1979     H  5.40  2.70
# 14  1979     I  6.40  1.20

# %% [markdown]
# Using this data answer the following questions:

# %% [markdown]
# * Create a hierarchical index for the DataFrame based on the ``year`` and ``indiv`` columns using the [set_index](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html) method.

# %%
# add a hierarchical index
data = data.set_index(['year', 'indiv'])
data
# Out:
#                x     z
# year indiv
# 1977 A      1.20  0.60
#      B      1.50  0.50
#      C      1.70  0.80
# 1978 A      0.20  0.06
#      B      0.70  0.20
#      C      0.80  0.30
#      D      0.90  0.50
#      E      1.40  0.90
# 1979 C      0.20  0.15
#      D      0.14  0.05
#      E      0.50  0.15
#      F      1.20  0.50
#      G      3.40  1.90
#      H      5.40  2.70
#      I      6.40  1.20

# %% [markdown]
# * Extract the data from 1977

# %%
# the 1977 data
data.loc[1977]
# Out:
#          x    z
# indiv
# A      1.2  0.6
# B      1.5  0.5
# C      1.7  0.8

# %% [markdown]
# * Extract the data for individual A

# %%
# the data for individual A
# keep in mind that the following won't work:
# data.loc[:, 'A']
# use pd.IndexSlice or reorder the levels of the index using the pandas 
# swaplevel method
data.loc[pd.IndexSlice[:, 'A'], :]
# Out:
#               x     z
# year indiv
# 1977 A      1.2  0.60
# 1978 A      0.2  0.06

# %% [markdown]
# * When performing `data.unstack()` on your multi-indexed DataFrame you get a lot of `Nan`s.  Explain why!

# %%
# data.unstack()
data.unstack()
# Out:
#          x                                              z  ...       Mean  \
# indiv    A    B    C     D    E    F    G    H    I     A  ...    I     A
# year                                                       ...
# 1977   1.2  1.5  1.7   NaN  NaN  NaN  NaN  NaN  NaN  0.60  ...  NaN  0.90
# 1978   0.2  0.7  0.8  0.90  1.4  NaN  NaN  NaN  NaN  0.06  ...  NaN  0.13
# 1979   NaN  NaN  0.2  0.14  0.5  1.2  3.4  5.4  6.4   NaN  ...  1.2   NaN
#
#
# indiv     B      C      D      E     F     G     H    I
# year
# 1977   1.00  1.250    NaN    NaN   NaN   NaN   NaN  NaN
# 1978   0.45  0.550  0.700  1.150   NaN   NaN   NaN  NaN
# 1979    NaN  0.175  0.095  0.325  0.85  2.65  4.05  3.8
#
# [3 rows x 27 columns]

# %% [markdown]
# <span style="color: brown;">Unstack() pivots one of the index levels into columns. If a particular combination, (such as 1977 & D), of index values are missing in the 'original' data frame, unstack() creates a placeholder for it, filling it in with NaN.</span>

# %% [markdown]
# * Run the statement `data['z'] == data.loc[:,'z']` and explain the result.

# %%
# data['z'] == data.loc[:,'z']
data['z'] == data.loc[:,'z']
# Out:
# year  indiv
# 1977  A        True
#       B        True
#       C        True
# 1978  A        True
#       B        True
#       C        True
#       D        True
#       E        True
# 1979  C        True
#       D        True
#       E        True
#       F        True
#       G        True
#       H        True
#       I        True
# Name: z, dtype: bool

# %% [markdown]
# <span style="color: brown;">If the column 'z' exists in the data frame, the comparison data['z'] == data.loc[:, 'z'] will return True for every row, since both expressions reference to the same column. The result will be a series of True values, indicating that the column values are identical when compared to themselves.</span>

# %% [markdown]
# * Add a new column to the data called `Mean` which equals the average of the two columns.  Use the `mean` method of a pandas DataFrame.

# %%
# add a mean column
data['Mean'] = data.mean(axis=1)
data
# Out:
#                x     z   Mean
# year indiv
# 1977 A      1.20  0.60  0.900
#      B      1.50  0.50  1.000
#      C      1.70  0.80  1.250
# 1978 A      0.20  0.06  0.130
#      B      0.70  0.20  0.450
#      C      0.80  0.30  0.550
#      D      0.90  0.50  0.700
#      E      1.40  0.90  1.150
# 1979 C      0.20  0.15  0.175
#      D      0.14  0.05  0.095
#      E      0.50  0.15  0.325
#      F      1.20  0.50  0.850
#      G      3.40  1.90  2.650
#      H      5.40  2.70  4.050
#      I      6.40  1.20  3.800
